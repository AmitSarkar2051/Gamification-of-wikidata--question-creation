# %%
import requests
url = 'https://query.wikidata.org/sparql'
query = """
SELECT 
  # ?countryLabel ?population ?area ?medianIncome ?age
WHERE {
  # ?country wdt:P463 wd:Q458.
  OPTIONAL { ?country wdt:P1082 ?population }
  OPTIONAL { ?country wdt:P2046 ?area }
  OPTIONAL { ?country wdt:P3529 ?medianIncome }
  OPTIONAL { ?country wdt:P571 ?inception. 
    BIND(year(now()) - year(?inception) AS ?age)
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
}
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

import pandas as pd
from collections import OrderedDict
countries = []
for item in data['results']['bindings']:
    countries.append(OrderedDict({
        'country': item['countryLabel']['value'],
        'population': item['population']['value'],
        'area': item['area']['value'] 
            if 'area' in item else None,
        'medianIncome': item['medianIncome']['value'] 
            if 'medianIncome' in item else None,
        'age': item['age']['value'] 
            if 'age' in item else None}))
df = pd.DataFrame(countries)
df.set_index('country', inplace=True)
df = df.astype({'population': float, 'area': float, 'medianIncome': float, 'age': float})
df.head()
# Out:
#                             population       area  medianIncome     age
# country
# Kingdom of Denmark           5930987.0  2220930.0           NaN  1220.0
# Kingdom of the Netherlands  17100715.0    42201.0           NaN   205.0
# Ireland                      4761865.0    70273.0       25969.0    83.0
# Belgium                     11431406.0    30528.0       31112.0   190.0
# Hungary                      9769526.0    93011.4           NaN  1020.0

# %%
import requests
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import random
url = 'https://query.wikidata.org/sparql'
query = """
    SELECT ?item ?itemLabel 
    WHERE 
    {
      # ?item wdt:P31 wd:Q11344.
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()
print(data)

# import pandas as pd
# from collections import OrderedDict
# countries = []
# for item in data['results']['bindings']:
#     countries.append(OrderedDict({
#         'country': item['countryLabel']['value'],
#         'population': item['population']['value'],
#         'area': item['area']['value'] 
#             if 'area' in item else None,
#         'medianIncome': item['medianIncome']['value'] 
#             if 'medianIncome' in item else None,
#         'age': item['age']['value'] 
#             if 'age' in item else None}))
# df = pd.DataFrame(countries)
# df.set_index('country', inplace=True)
# df = df.astype({'population': float, 'area': float, 'medianIncome': float, 'age': float})
# df.head()
# Out:
# {'head': {'vars': ['item', 'itemLabel']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q556'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'hydrogen'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q560'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'helium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q568'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'lithium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q569'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'beryllium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q618'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'boron'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q623'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'carbon'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q627'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'nitrogen'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q629'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'oxygen'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q650'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'fluorine'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q654'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'neon'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q658'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'sodium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q660'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'magnesium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q663'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'aluminum'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q670'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'silicon'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q671'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'francium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q674'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'phosphorus'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q677'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'iron'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q682'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'sulfur'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q688'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'chlorine'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q696'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'argon'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q703'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'potassium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q706'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'calcium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q708'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'lead'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q713'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'scandium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q716'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'titanium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q722'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'vanadium'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q725'}, 'itemLabel': {'xml:lang': 'en', 'type ...

# %%
import json
print(json.dumps(data, indent=2))
# Out:
# {
#   "head": {
#     "vars": [
#       "item",
#       "itemLabel"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q556"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "hydrogen"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q560"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "helium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q568"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "lithium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q569"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "beryllium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q618"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boron"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q623"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "carbon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q627"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "nitrogen"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q629"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "oxygen"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q650"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "fluorine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q654"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "neon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q658"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "sodium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q660"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "magnesium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q663"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "aluminum"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q670"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "silicon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q671"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "francium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q674"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "phosphorus"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q677"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "iron"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q682"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "sulfur"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q688"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "chlorine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q696"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "argon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q703"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "potassium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q706"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "calcium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q708"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "lead"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q713"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "scandium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q716"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "titanium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q722"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "vanadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q725"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "chromium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q731"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "manganese"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q737"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "rhenium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q740"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "cobalt"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q743"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "tungsten"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q744"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "nickel"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q751"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "osmium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q753"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "copper"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q758"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "zinc"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q861"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "gallium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q867"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "germanium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q871"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "arsenic"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q876"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "selekk"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q877"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "iridium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q879"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "bromine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q880"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "platinum"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q888"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "krypton"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q895"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "rubidium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q897"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "gold"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q925"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "mercury"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q932"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "thallium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q938"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "strontium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q941"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "yttrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q942"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "bismuth"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q979"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "polonium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q999"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "astatine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1038"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "zirconium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1046"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "niobium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1053"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "molybdenum"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1054"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "technetium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1086"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ruthenium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1087"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "rhodium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1089"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "palladium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1090"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "silver"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1091"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "cadmium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1094"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "indium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1096"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "tin"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1098"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "uranium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1099"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "antimony"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1100"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "tellurium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1102"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "plutonium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1103"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "iodine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1105"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "neptunium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1106"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "xenon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1108"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "caesium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1109"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "protactinium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1112"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "barium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1115"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "thorium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1119"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "hafnium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1121"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "actinium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1123"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "tantalum"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1128"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "radium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1133"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "radon"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1139"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ununennium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1146"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbinilium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1226"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "rutherfordium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1232"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "dubnium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1234"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "seaborgium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1249"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "bohrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1252"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "hassium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1258"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "meitnerium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1266"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "darmstadtium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1272"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "roentgenium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1278"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "copernicium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1301"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "nihonium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1302"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "flerovium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1303"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "moscovium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1304"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "livermorium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1306"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "tennessine"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1307"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "oganesson"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1385"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "cerium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1386"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "praseodymium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1388"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "neodymium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1396"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "europium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1466"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbiunium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1801"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "lanthanum"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1809"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "promethium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1819"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "samarium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1832"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "gadolinium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1838"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "terbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1843"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "dysprosium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1846"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "holmium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1849"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "erbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1853"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "thulium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1855"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ytterbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1857"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "lutetium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1872"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "americium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1876"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "curium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1882"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "berkelium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1888"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "californium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1892"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "einsteinium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1896"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "fermium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1898"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "mendelevium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1901"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "nobelium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1905"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "lawrencium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q7425"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbibium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q54377"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbihexium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428629"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untriunium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428635"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untribium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428640"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbiennium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428648"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untrinilium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428685"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbipentium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428692"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbiseptium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428703"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbioctium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428741"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbiquadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q428758"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unbitrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q548592"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untriennium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q868375"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untrihexium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q869681"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untrioctium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q1366419"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untriseptium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q2399140"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadennium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3029913"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadnilium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551918"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551919"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentnilium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551921"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentunium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551924"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpenttrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551926"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadhexium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551927"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551928"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadoctium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551929"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadseptium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551930"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadpentium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551931"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadquadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551933"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadtrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3551935"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unquadunium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3552038"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untripentium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3552040"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untriquadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q3552041"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "untritrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q11289368"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unsepttrium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q16307164"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unseptbium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q16307168"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexoctium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q16307173"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexseptium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q16307178"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexpentium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q19599218"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexennium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q22313918"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentquadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q22314315"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentpentium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q30929350"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexquadium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q91655950"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpenthexium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q91655961"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentseptium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q91655977"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentoctium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q91655999"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unhexnilium"
#         }
#       },
#       {
#         "item": {
#           "type": "uri",
#           "value": "http://www.wikidata.org/entity/Q92113383"
#         },
#         "itemLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "unpentennium"
#         }
#       }
#     ]
#   }
# }

# %%
query = """SELECT ?wdLabel {
	  VALUES (?element) {(wd:"""+str("Q560")+""")}

	  # ?element ?p ?statement .
	  

	  # ?wd wikibase:claim ?p.
	  

	  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
	} ORDER BY ?wd ?statement ?ps_"""


r2 = requests.get(url, params = {'format': 'json', 'query': query})
data2 = r2.json()
print(json.dumps(data2, indent=2))
# Out:
# {
#   "head": {
#     "vars": [
#       "wdLabel"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "named after"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "image"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "GND ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAS Registry Number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "EC number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "canonical SMILES"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChIKey"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Library of Congress authority ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "element symbol"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "instance of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PSH ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "atomic number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electronegativity"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "refractive index"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "U.S. National Archives Identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "OmegaWiki Defined Meaning"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Britannica Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "density"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "mass"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NDF-RT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "YSO ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ECHA InfoCard ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Biblioth\u00e8que nationale de France ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "chemical formula"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "by-product of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UMLS CUI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Great Russian Encyclopedia Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "standard molar entropy"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTox substance ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Universalis ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NE.se ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "RxNorm ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Treccani ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Quora topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "National Diet Library ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "JSTOR topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "conjugate acid"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode hex codepoint"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Store norske leksikon ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ASHRAE refrigerant number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH descriptor ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode character"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Brockhaus Enzyklop\u00e4die online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "R\u00f6mpp online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "BNCF Thesaurus ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Common Procurement Vocabulary"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "time of discovery or invention"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEMBL ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "E number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Microsoft Academic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Freebase ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UNII"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Klexikon article ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChemSpider ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PubChem CID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ZVG number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEBI ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NKCR AUT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Australian Educational Vocabulary ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "AICS Chemical ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DrugBank ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "French Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Italian Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electron configuration"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAB ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "KBpedia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTOX compound identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "topic's main category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons gallery"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "spoken text audio"
#         }
#       }
#     ]
#   }
# }

# %%
for result in data2["results"]["bindings"]:
		if result['wdLabel']['value'][0] != 'P':
			print(str(result['wdLabel']['value'])+'\n')
# Out:
# named after
#
# image
#
# GND ID
#
# CAS Registry Number
#
# EC number
#
# canonical SMILES
#
# InChI
#
# InChIKey
#
# Library of Congress authority ID
#
# element symbol
#
# instance of
#
# discoverer or inventor
#
# discoverer or inventor
#
# atomic number
#
# electronegativity
#
# refractive index
#
# U.S. National Archives Identifier
#
# OmegaWiki Defined Meaning
#
# described by source
#
# described by source
#
# Encyclopædia Britannica Online ID
#
# has quality
#
# has quality
#
# has quality
#
# density
#
# mass
#
# speed of sound
#
# speed of sound
#
# melting point
#
# melting point
#
# melting point
#
# melting point
#
# boiling point
#
# boiling point
#
# NDF-RT ID
#
# YSO ID
#
# ECHA InfoCard ID
#
# Bibliothèque nationale de France ID
#
# chemical formula
#
# subclass of
#
# subclass of
#
# subclass of
#
# by-product of
#
# UMLS CUI
#
# Great Russian Encyclopedia Online ID
#
# standard molar entropy
#
# DSSTox substance ID
#
# Encyclopædia Universalis ID
#
# NE.se ID
#
# RxNorm ID
#
# Treccani ID
#
# Quora topic ID
#
# National Diet Library ID
#
# part of
#
# part of
#
# use
#
# use
#
# use
#
# use
#
# Commons category
#
# JSTOR topic ID
#
# conjugate acid
#
# Unicode hex codepoint
#
# Store norske leksikon ID
#
# ASHRAE refrigerant number
#
# MeSH descriptor ID
#
# Unicode character
#
# Brockhaus Enzyklopädie online ID
#
# Römpp online ID
#
# BNCF Thesaurus ID
#
# Common Procurement Vocabulary
#
# time of discovery or invention
#
# ChEMBL ID
#
# E number
#
# Microsoft Academic ID
#
# Freebase ID
#
# UNII
#
# Klexikon article ID
#
# ChemSpider ID
#
# MeSH tree code
#
# MeSH tree code
#
# ZVG number
#
# ChEBI ID
#
# NKCR AUT ID
#
# Australian Educational Vocabulary ID
#
# AICS Chemical ID
#
# DrugBank ID
#
# French Vikidia ID
#
# Italian Vikidia ID
#
# electron configuration
#
# CAB ID
#
# KBpedia ID
#
# DSSTOX compound identifier
#
# topic's main category
#
# Commons gallery
#
# spoken text audio

# %%
query = """SELECT ?wdLabel {
	  VALUES (?element) {(wd:"""+str("Q560")+""")}

	  # ?element ?p ?statement .
	  

	  # ?wd wikibase:claim ?p.
	  

	  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
	}"""


r2 = requests.get(url, params = {'format': 'json', 'query': query})
data2 = r2.json()
print(json.dumps(data2, indent=2))
# Out:
# {
#   "head": {
#     "vars": [
#       "wdLabel"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ZVG number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEBI ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NKCR AUT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DrugBank ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "topic's main category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons gallery"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "spoken text audio"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PSH ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "atomic number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electronegativity"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "refractive index"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "U.S. National Archives Identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "OmegaWiki Defined Meaning"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Britannica Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "density"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "mass"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NDF-RT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "YSO ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ECHA InfoCard ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "by-product of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UMLS CUI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Great Russian Encyclopedia Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "standard molar entropy"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTox substance ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Universalis ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NE.se ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "RxNorm ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Treccani ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Quora topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "JSTOR topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "conjugate acid"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode hex codepoint"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Store norske leksikon ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ASHRAE refrigerant number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Brockhaus Enzyklop\u00e4die online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "R\u00f6mpp online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Common Procurement Vocabulary"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Microsoft Academic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Klexikon article ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Australian Educational Vocabulary ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "AICS Chemical ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "French Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Italian Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electron configuration"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAB ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "KBpedia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTOX compound identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "image"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "instance of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "named after"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "GND ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAS Registry Number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "EC number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "canonical SMILES"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChIKey"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Library of Congress authority ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "element symbol"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Biblioth\u00e8que nationale de France ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "chemical formula"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "National Diet Library ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH descriptor ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode character"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "BNCF Thesaurus ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "time of discovery or invention"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEMBL ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "E number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Freebase ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UNII"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChemSpider ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PubChem CID"
#         }
#       }
#     ]
#   }
# }

# %%
for result in data2["results"]["bindings"]:
		if result['wdLabel']['value'][0] != 'P':
			print(str(result['wdLabel']['value'])+'\n')
# Out:
# MeSH tree code
#
# MeSH tree code
#
# ZVG number
#
# ChEBI ID
#
# NKCR AUT ID
#
# DrugBank ID
#
# topic's main category
#
# Commons gallery
#
# spoken text audio
#
# atomic number
#
# electronegativity
#
# refractive index
#
# U.S. National Archives Identifier
#
# OmegaWiki Defined Meaning
#
# described by source
#
# described by source
#
# Encyclopædia Britannica Online ID
#
# has quality
#
# has quality
#
# has quality
#
# density
#
# mass
#
# speed of sound
#
# speed of sound
#
# melting point
#
# melting point
#
# melting point
#
# melting point
#
# boiling point
#
# boiling point
#
# NDF-RT ID
#
# YSO ID
#
# ECHA InfoCard ID
#
# by-product of
#
# UMLS CUI
#
# Great Russian Encyclopedia Online ID
#
# standard molar entropy
#
# DSSTox substance ID
#
# Encyclopædia Universalis ID
#
# NE.se ID
#
# RxNorm ID
#
# Treccani ID
#
# Quora topic ID
#
# JSTOR topic ID
#
# conjugate acid
#
# Unicode hex codepoint
#
# Store norske leksikon ID
#
# ASHRAE refrigerant number
#
# Brockhaus Enzyklopädie online ID
#
# Römpp online ID
#
# Common Procurement Vocabulary
#
# Microsoft Academic ID
#
# Klexikon article ID
#
# Australian Educational Vocabulary ID
#
# AICS Chemical ID
#
# French Vikidia ID
#
# Italian Vikidia ID
#
# electron configuration
#
# CAB ID
#
# KBpedia ID
#
# DSSTOX compound identifier
#
# image
#
# instance of
#
# discoverer or inventor
#
# discoverer or inventor
#
# named after
#
# GND ID
#
# CAS Registry Number
#
# EC number
#
# canonical SMILES
#
# InChI
#
# InChIKey
#
# Library of Congress authority ID
#
# element symbol
#
# Bibliothèque nationale de France ID
#
# chemical formula
#
# subclass of
#
# subclass of
#
# subclass of
#
# National Diet Library ID
#
# part of
#
# part of
#
# use
#
# use
#
# use
#
# use
#
# Commons category
#
# MeSH descriptor ID
#
# Unicode character
#
# BNCF Thesaurus ID
#
# time of discovery or invention
#
# ChEMBL ID
#
# E number
#
# Freebase ID
#
# UNII
#
# ChemSpider ID

# %%
query = """SELECT ?wdLabel {
	  VALUES (?element) {(wd:"""+str("Q560")+""")}

	  # ?element ?p ?statement .
	  

	  # ?wd wikibase:claim ?p.

	  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
	}"""


r2 = requests.get(url, params = {'format': 'json', 'query': query})
data2 = r2.json()
print(json.dumps(data2, indent=2))
# Out:
# {
#   "head": {
#     "vars": [
#       "wdLabel"
#     ]
#   },
#   "results": {
#     "bindings": [
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH tree code"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ZVG number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEBI ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NKCR AUT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DrugBank ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "topic's main category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons gallery"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "spoken text audio"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PSH ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "atomic number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electronegativity"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "refractive index"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "U.S. National Archives Identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "OmegaWiki Defined Meaning"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "described by source"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Britannica Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "has quality"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "density"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "mass"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "speed of sound"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "melting point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "boiling point"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NDF-RT ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "YSO ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ECHA InfoCard ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "by-product of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UMLS CUI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Great Russian Encyclopedia Online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "standard molar entropy"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTox substance ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Encyclop\u00e6dia Universalis ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "NE.se ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "RxNorm ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Treccani ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Quora topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "JSTOR topic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "conjugate acid"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode hex codepoint"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Store norske leksikon ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ASHRAE refrigerant number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Brockhaus Enzyklop\u00e4die online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "R\u00f6mpp online ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Common Procurement Vocabulary"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Microsoft Academic ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Klexikon article ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Australian Educational Vocabulary ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "AICS Chemical ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "French Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Italian Vikidia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "electron configuration"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAB ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "KBpedia ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "DSSTOX compound identifier"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "image"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "instance of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "discoverer or inventor"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "named after"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "GND ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "CAS Registry Number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "EC number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "canonical SMILES"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChI"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "InChIKey"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Library of Congress authority ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "element symbol"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Biblioth\u00e8que nationale de France ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "chemical formula"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "subclass of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "National Diet Library ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "part of"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "use"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Commons category"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "MeSH descriptor ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Unicode character"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "BNCF Thesaurus ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "time of discovery or invention"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChEMBL ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "E number"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "Freebase ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "UNII"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "ChemSpider ID"
#         }
#       },
#       {
#         "wdLabel": {
#           "xml:lang": "en",
#           "type": "literal",
#           "value": "PubChem CID"
#         }
#       }
#     ]
#   }
# }

# %%
import os 
import sys
import random

files=os.listdir('chemical_elements')
first_file=random.choice(files)
second_file=first_file
while second_file==first_file:
	second_file=random.choice(files)

file=open('chemical_elements/'+first_file,'r')
temp=file.readlines()
first=set()
for i in temp:
	first.add(i.strip())

file=open('chemical_elements/'+second_file,'r')
temp=file.readlines()
second=set()
for i in temp:
	second.add(i.strip())

difference=list(first-second)
value=random.choice(difference)
print(first_file)

print('तत्व '+str(second_file)+ ' का '+str(value)+' क्या है?')
# Out:
# सोडियम
# तत्व कोबाल्ट का इससे अलग क्या है?

# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import random

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?item ?itemLabel 
WHERE 
{
  # ?item wdt:P31 wd:Q11344.
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],hi". }
}"""

# def get_results(endpoint_url, query):
#     user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
#     # TODO adjust user agent; see https://w.wiki/CX6
#     sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
#     sparql.setQuery(query)
#     sparql.setReturnFormat(JSON)
#     return sparql.query().convert()

r = requests.get(url, params = {'format': 'json', 'query': query})
results = r.json()
# print(data)
# results = get_results(endpoint_url, query)
print("HERE0")
all_elements=[] # stores item name code eg: Q560
names=[] #stores name of item eg: helium
for result in results["results"]["bindings"]:
    all_elements.append(result['item']['value'].split('/')[-1])
    names.append(result['itemLabel']['value'])

properties_list=[]
count=0
print("HERE")
for i in range(0,1):  ## ?wd wikibase:claim ?p. isse saare properties aa ja re
    query = """SELECT ?wdLabel {
      VALUES (?element) {(wd:"""+str(all_elements[i])+""")}

      # ?element ?p ?statement .


      # ?wd wikibase:claim ?p. 


      SERVICE wikibase:label { bd:serviceParam wikibase:language "hi" }
    } ORDER BY ?wd ?statement ?ps_"""
    #ORDER BY ?wd ?statement ?ps_""" se alphabetical order me properties aare

    def get_results(endpoint_url, query):
        user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
        # TODO adjust user agent; see https://w.wiki/CX6
        sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        return sparql.query().convert()
    r = requests.get(url, params = {'format': 'json', 'query': query})
    results = r.json()


    #file=open(names[i],'w')
    # 	for i in properties_list:
    # 		for j in i:
    # 			print("hi")
    # 			print(j)
    # 	results = get_results(endpoint_url, query)

#     print(json.dumps(results, indent=2))
    for result in results["results"]["bindings"]:
        if result['wdLabel']['value'][0] != '':
            print(str(result['wdLabel']['value'])+'\n')
#     	file.close()
# Out:
# HERE0
# HERE
# द्वारा नामांकित
#
# चित्र
#
# ख़ोज की जगह
#
# ख़ोज की जगह
#
# ख़ोज की जगह
#
# GND अभिज्ञापक
#
# P231
#
# LCCN अभिज्ञापक
#
# P246
#
# का उदहारण है
#
# खोजकर्ता या आविष्कारक
#
# खोजकर्ता या आविष्कारक
#
# खोजकर्ता या आविष्कारक
#
# P1014
#
# P1036
#
# P1036
#
# P1051
#
# P1086
#
# P1108
#
# P1109
#
# P1121
#
# P1121
#
# P1121
#
# P1245
#
# स्रोत द्वारा वर्णित
#
# P1417
#
# इससे अलग
#
# इससे अलग
#
# इससे अलग
#
# P2054
#
# द्रव्यमान
#
# उष्मा समीकरण
#
# ध्वनि का वेग
#
# P2101
#
# P2102
#
# P2114
#
# P2116
#
# P2152
#
# P2260
#
# P2347
#
# P2581
#
# P268
#
# का उपवर्ग
#
# का उपवर्ग
#
# का उपवर्ग
#
# P2924
#
# P2959
#
# P3219
#
# P3222
#
# P3365
#
# P3417
#
# NDL पहचानकर्ता
#
# P3569
#
# का भाग
#
# का भाग
#
# कॉमन्स श्रेणी
#
# P3827
#
# P3916
#
# P4213
#
# रंग
#
# P4839
#
# P486
#
# P487
#
# P5008
#
# P5019
#
# P5076
#
# BNCF कोश
#
# P575
#
# P6366
#
# फ्रीबेस पहचानकर्ता
#
# P6573
#
# P672
#
# P672
#
# P683
#
# P6900
#
# P7033
#
# P7818
#
# P7822
#
# P7827
#
# P7829
#
# P8000
#
# P8408
#
# विषय की मुख्य श्रेणी
#
# कॉमन्स गैलरी
#
# P950

# %%
import requests
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import random
url = 'https://query.wikidata.org/sparql'
query = """
    SELECT ?item ?itemLabel 
    WHERE 
    {
      # ?item wdt:P31 wd:Q21294996 .
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()
print(data)
# Out:
# {'head': {'vars': ['item', 'itemLabel']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5040'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'GHS hazard pictogram'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5041'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'GHS hazard statement'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5042'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'GHS precautionary statement'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5219'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'BMRB ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5220'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'ICSC ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P5929'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'limiting oxygen index'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6185'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'tautomer of'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6272'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'specific rotation'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6274'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'concentration'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6680'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'MeSH term ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6689'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'MassBank accession ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P6694'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'MeSH concept ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7001'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'PharmGKB ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7025'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'HCIS ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7746'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Natural Product Atlas ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P7999'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Haz-Map ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8000'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'electron configuration'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8117'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'FooDB compound ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8120'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'ModelSEED compound ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8121'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'UM-BBD compound ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8224'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'molecular model or crystal lattice model'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8266'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'FEMA number'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8354'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'BitterDB compound ID'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8459'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'descriptive solubility'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/P8465'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value':  ...

# %%
SELECT ?p1080 ?pLabel ?w ?wLabel WHERE {
   wd:Q p:P6/ps:P6 ?p .
   # ?p wdt:P26 ?w .
   SERVICE wikibase:label {
    bd:serviceParam wikibase:language "en" .
   }
 }
# Out:
#   File "<ipython-input-40-1ec873f2208a>", line 1
#     SELECT * WHERE {
#                    ^
# SyntaxError: invalid syntax

# %%
x="P1086"
query = """
SELECT  *
WHERE {
        wd:x rdfs:label ?label .
        FILTER (langMatches( lang(?label), "EN" ) )
      } 
LIMIT 1

"""
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()
# print(data)
print(json.dumps(data, indent=2))
# Out:
# {
#   "head": {
#     "vars": [
#       "label"
#     ]
#   },
#   "results": {
#     "bindings": []
#   }
# }

# %%
for result in data["results"]["bindings"]:
    print(str(result['label']['value']))
# Out:
# atomic number

# %%
import os 
import sys
import random
import sqlite3
from collections import defaultdict

# con=sqlite3.connect('questions.db')
# con.execute('CREATE TABLE IF NOT EXISTS theorems (SERIAL_NO Int NOT NULL, QUESTION TEXT NOT NULL) ;')
# conn=con.cursor()

files=os.listdir('chem_folder')
properties=defaultdict(int)
for i in files:
	# print(i)
	i=i.strip()
	file=open('chemical_elements/'+i,'r')
	temp=file.readlines()
	first=set()
	for j in temp:
		first.add(j.strip())
	for j in first:
		properties[j]+=1

print(properties.keys())
# final_properties=[]
# for i in properties:
# 	properties[i]/=len(files)
# 	if properties[i]>=0.75:
# 		final_properties.append(i)

# # print(final_properties)
# print(len(final_properties))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6f851fa21c3e> in <module>
#      14         # print(i)
#      15         i=i.strip()
# ---> 16         file=open('chemical_elements/'+i,'r')
#      17         temp=file.readlines()
#      18         first=set()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chemical_elements/कैडमियम'

# %%
import os 
import sys
import random
import sqlite3
from collections import defaultdict

# con=sqlite3.connect('questions.db')
# con.execute('CREATE TABLE IF NOT EXISTS theorems (SERIAL_NO Int NOT NULL, QUESTION TEXT NOT NULL) ;')
# conn=con.cursor()

files=os.listdir('chem_folder')
properties=defaultdict(int)
for i in files:
	# print(i)
	i=i.strip()
	file=open('chem_folder/'+i,'r')
	temp=file.readlines()
	first=set()
	for j in temp:
		first.add(j.strip())
	for j in first:
		properties[j]+=1

final_properties=[]
for i in properties:
	properties[i]/=len(files)
	if properties[i]>=0.75:
		final_properties.append(i)

print(final_properties)
print(len(final_properties))
# Out:
# ['खोजकर्ता या आविष्कारक', 'GND अभिज्ञापक', 'DSSTOX_compound_identifier', 'कॉमन्स गैलरी', 'विषय की मुख्य श्रेणी', 'time of discovery or invention', 'फ्रीबेस पहचानकर्ता', 'चित्र', 'द्रव्यमान', 'Unicode character', 'का भाग', 'UNII', 'कॉमन्स श्रेणी', 'LCCN अभिज्ञापक', 'chemical formula', 'Encyclopædia Britannica Online ID', 'का उदहारण है', 'स्रोत द्वारा वर्णित', 'Treccani ID']
# 19

# %%
import os 
import sys
import random
import sqlite3
from collections import defaultdict

# con=sqlite3.connect('questions.db')
# con.execute('CREATE TABLE IF NOT EXISTS theorems (SERIAL_NO Int NOT NULL, QUESTION TEXT NOT NULL) ;')
# conn=con.cursor()

files=os.listdir('chem_folder')
properties=defaultdict(int)
for i in files:
	# print(i)
	i=i.strip()
	file=open('chem_folder/'+i,'r')
	temp=file.readlines()
	first=set()
	for j in temp:
		first.add(j.strip())
	for j in first:
		properties[j]+=1

final_properties=[]
for i in properties:
	properties[i]/=len(files)
	if properties[i]>=0.50:
		final_properties.append(i)

print(final_properties)
# Out:
# ['खोजकर्ता या आविष्कारक', 'NDL पहचानकर्ता', 'GND अभिज्ञापक', 'DSSTOX_compound_identifier', 'कॉमन्स गैलरी', 'विषय की मुख्य श्रेणी', 'BNCF कोश', 'time of discovery or invention', 'फ्रीबेस पहचानकर्ता', 'चित्र', 'द्वारा नामांकित', 'द्रव्यमान', 'Unicode character', 'का भाग', 'UNII', 'कॉमन्स श्रेणी', 'LCCN अभिज्ञापक', 'chemical formula', 'Encyclopædia Britannica Online ID', 'का उदहारण है', 'स्रोत द्वारा वर्णित', 'Treccani ID', 'का उपवर्ग']

# %%
import os 
import sys
import random
while(1):
    files=os.listdir('chem_folder')
    first_file=random.choice(files)
    second_file=first_file
    while second_file==first_file:
        second_file=random.choice(files)

    file=open('chem_folder/'+first_file,'r')
    temp=file.readlines()
    first=set()
    for i in temp:
        first.add(i.strip())

    file=open('chemical_elements/'+second_file,'r')
    temp=file.readlines()
    second=set()
    for i in temp:
        second.add(i.strip())

    difference=list(first-second)
    value=random.choice(difference)

    if(value in final_properties):
        print('तत्व '+str(second_file)+ ' का '+ '\"' +str(value)+'\"'+' क्या है?')
        break
# Out:
# तत्व ऑक्सीजन का "का भाग" क्या है?

# %%
## question from old properties
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'../question_sch.db')
# create the dataframe from a query
df = pd.read_sql_query("SELECT * FROM ELEMENTS", cnx)
df.to_csv('ques.csv',index=False)

# %%
### ques after adding english properties
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'questions_new.db')

# create the dataframe from a query
df = pd.read_sql_query("SELECT * FROM ELEMENTS", cnx)
df
# Out:
#      SERIAL_NO                                           QUESTION
# 0            1                  तत्व नाइट्रोजन का "UNII" क्या है?
# 1            2      तत्व नाइट्रोजन का "chemical formula" क्या है?
# 2            3  तत्व नाइट्रोजन का "DSSTOX_compound_identifier"...
# 3            4         तत्व मेइट्नेरियम का "Treccani ID" क्या है?
# 4            5      तत्व मेइट्नेरियम का "LCCN अभिज्ञापक" क्या है?
# ..         ...                                                ...
# 185        186         तत्व थोरियम का "chemical formula" क्या है?
# 186        187                तत्व क्षुद्रातु का "चित्र" क्या है?
# 187        188            तत्व क्षुद्रातु का "द्रव्यमान" क्या है?
# 188        189                     तत्व रेडॉन का "चित्र" क्या है?
# 189        190                 तत्व रेडॉन का "द्रव्यमान" क्या है?
#
# [190 rows x 2 columns]

# %%
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'../questions_new.db')

# create the dataframe from a query
df = pd.read_sql_query("SELECT * FROM ELEMENTS", cnx)
df
# Out:
#      SERIAL_NO                                           QUESTION
# 0            1  तत्व नाइट्रोजन का "DSSTOX_compound_identifier"...
# 1            2                  तत्व नाइट्रोजन का "UNII" क्या है?
# 2            3      तत्व नाइट्रोजन का "chemical formula" क्या है?
# 3            4  तत्व मेइट्नेरियम का "DSSTOX_compound_identifie...
# 4            5      तत्व मेइट्नेरियम का "LCCN अभिज्ञापक" क्या है?
# ..         ...                                                ...
# 185        186         तत्व थोरियम का "chemical formula" क्या है?
# 186        187                तत्व क्षुद्रातु का "चित्र" क्या है?
# 187        188            तत्व क्षुद्रातु का "द्रव्यमान" क्या है?
# 188        189                     तत्व रेडॉन का "चित्र" क्या है?
# 189        190                 तत्व रेडॉन का "द्रव्यमान" क्या है?
#
# [190 rows x 2 columns]

# %%
from inltk.inltk import get_similar_sentences

# get similar sentences to the one given in hindi
output = get_similar_sentences('मैं आज बहुत खुश हूं', 5, 'hi')

print(output)

# %%
import stanfordnlp

# %%
stanfordnlp.download('hi')
# Out:
# Using the default treebank "hi_hdtb" for language "hi".
# Would you like to download the models for: hi_hdtb now? (Y/n)
# y
#
# Default download directory: /home/kumar/stanfordnlp_resources
# Hit enter to continue or type an alternate directory.
#
#
# Downloading models for: hi_hdtb
# Download location: /home/kumar/stanfordnlp_resources/hi_hdtb_models.zip
# 100%|██████████| 208M/208M [04:41<00:00, 739kB/s]
# Download complete.  Models saved to: /home/kumar/stanfordnlp_resources/hi_hdtb_models.zip
# Extracting models file for: hi_hdtb
# Cleaning up...Done.

# %%
nlp = stanfordnlp.Pipeline(lang="hi", treebank="hi_hdtb")
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tokenizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tagger.pt', 'pretrain_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_lemmatizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_parser.pt', 'pretrain_path': '/home/kumar/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
hindi_doc = nlp("""केंद्र की मोदी सरकार ने शुक्रवार को अपना अंतरिम बजट पेश किया. कार्यवाहक वित्त मंत्री पीयूष गोयल ने अपने बजट में किसान, मजदूर, करदाता, महिला वर्ग समेत हर किसी के लिए बंपर ऐलान किए. हालांकि, बजट के बाद भी टैक्स को लेकर काफी कन्फ्यूजन बना रहा. केंद्र सरकार के इस अंतरिम बजट क्या खास रहा और किसको क्या मिला, आसान भाषा में यहां समझें""")
# Out:
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
import pandas as pd
#extract parts of speech
def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)
words=['द्वारा नामांकित', 'कॉमन्स श्रेणी', 'का उपवर्ग', 'विषय की मुख्य श्रेणी', 'BNCF कोश', 'द्रव्यमान', 'GND अभिज्ञापक', 'फ्रीबेस पहचानकर्ता', 'कॉमन्स गैलरी', 'LCCN अभिज्ञापक', 'NDL पहचानकर्ता', 'स्रोत द्वारा वर्णित', 'खोजकर्ता या आविष्कारक', 'उदहारण है', 'चित्र', 'ख़ोज की जगह', 'इससे अलग', 'का भाग', 'राष्ट्रीय पुस्तकालय चेक गणराज्य पहचानकर्ता', 'उष्मा समीकरण', 'रंग', 'ध्वनि का वेग', 'नाम', 'पिछला है', 'अगला है', 'देशी लेबल', 'मानचित्र छवि', 'लोगो चित्र']
for w in words:
    hindi_doc = nlp(w)
    pos_dict = {
    'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
    'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
    'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
    'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
    'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
    'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
    'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
    'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
    'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
    'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
    'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
    'VB': 'verb, base form take','VBD': 'verb, past tense took',
    'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
    'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
    'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
    'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
    'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
    }
    print(extract_pos(hindi_doc))
# Out:
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#        word  pos                                   exp
# 0    द्वारा  PSP  postposition, common in indian langs
# 1  नामांकित   JJ                       adjective 'big'
#      word pos                    exp
# 0  कॉमन्स  VM              main verb
# 1  श्रेणी  NN  noun, singular 'desk'
#      word  pos                                   exp
# 0      का  PSP  postposition, common in indian langs
# 1  उपवर्ग   NN                 noun, singular 'desk'
#      word  pos                                   exp
# 0    विषय   NN                 noun, singular 'desk'
# 1      की  PSP  postposition, common in indian langs
# 2   मुख्य   JJ                       adjective 'big'
# 3  श्रेणी   NN                 noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#    word  pos                               exp
# 0  BNCF  NNP  proper noun, singular 'Harrison'
# 1   कोश   NN             noun, singular 'desk'
#         word pos                    exp
# 0  द्रव्यमान  NN  noun, singular 'desk'
#         word   pos                    exp
# 0        GND  NNPC                     NA
# 1  अभिज्ञापक    NN  noun, singular 'desk'
#          word  pos                               exp
# 0     फ्रीबेस  NNP  proper noun, singular 'Harrison'
# 1  पहचानकर्ता   VM                         main verb
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#      word pos                    exp
# 0  कॉमन्स  VM              main verb
# 1   गैलरी  NN  noun, singular 'desk'
#         word   pos                               exp
# 0       LCCN  NNPC                                NA
# 1  अभिज्ञापक   NNP  proper noun, singular 'Harrison'
#          word   pos                    exp
# 0         NDL  NNPC                     NA
# 1  पहचानकर्ता    NN  noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#      word  pos                                   exp
# 0   स्रोत   NN                 noun, singular 'desk'
# 1  द्वारा  PSP  postposition, common in indian langs
# 2  वर्णित   JJ                       adjective 'big'
#         word pos                       exp
# 0   खोजकर्ता  NN     noun, singular 'desk'
# 1         या  CC  coordinating conjunction
# 2  आविष्कारक  NN     noun, singular 'desk'
#      word pos                    exp
# 0  उदहारण  NN  noun, singular 'desk'
# 1      है  VM              main verb
#     word pos                    exp
# 0  चित्र  NN  noun, singular 'desk'
#    word  pos                                   exp
# 0  ख़ोज   NN                 noun, singular 'desk'
# 1    की  PSP  postposition, common in indian langs
# 2   जगह   NN                 noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#    word  pos                                   exp
# 0  इससे  PRP           personal pronoun I, he, she
# 1   अलग  PSP  postposition, common in indian langs
#   word  pos                                   exp
# 0   का  PSP  postposition, common in indian langs
# 1  भाग   NN                 noun, singular 'desk'
#          word   pos                               exp
# 0   राष्ट्रीय  NNPC                                NA
# 1   पुस्तकालय  NNPC                                NA
# 2         चेक  NNPC                                NA
# 3     गणराज्य   NNP  proper noun, singular 'Harrison'
# 4  पहचानकर्ता   NNP  proper noun, singular 'Harrison'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#      word  pos                    exp
# 0   उष्मा  NNC                     NA
# 1  समीकरण   NN  noun, singular 'desk'
#   word pos                    exp
# 0  रंग  NN  noun, singular 'desk'
#     word  pos                                   exp
# 0  ध्वनि   NN                 noun, singular 'desk'
# 1     का  PSP  postposition, common in indian langs
# 2    वेग   NN                 noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#   word pos                    exp
# 0  नाम  NN  noun, singular 'desk'
#     word pos              exp
# 0  पिछला  JJ  adjective 'big'
# 1     है  VM        main verb
#    word pos              exp
# 0  अगला  JJ  adjective 'big'
# 1    है  VM        main verb
#    word pos                    exp
# 0  देशी  JJ        adjective 'big'
# 1  लेबल  NN  noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
#        word pos                    exp
# 0  मानचित्र  JJ        adjective 'big'
# 1       छवि  NN  noun, singular 'desk'
#     word pos                    exp
# 0   लोगो  NN  noun, singular 'desk'
# 1  चित्र  NN  noun, singular 'desk'
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
hindi_doc = nlp("""तत्व रेडॉन का द्रव्यमान कौन है?""")
# Out:
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
import pandas as pd
pos_dict = {
'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take','VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
}

#extract parts of speech
def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)

# %%
extract_pos(hindi_doc)
# Out:
#                           word   pos                                   exp
# 0                     खोजकर्ता    NN                 noun, singular 'desk'
# 1                           या    CC              coordinating conjunction
# 2                    आविष्कारक    NN                 noun, singular 'desk'
# 3                    अभिज्ञापक    JJ                       adjective 'big'
# 4   DSSTOX_compound_identifier    VM                             main verb
# 5                       कॉमन्स    VM                             main verb
# 6                        गैलरी   NNC                                    NA
# 7                         विषय    NN                 noun, singular 'desk'
# 8                           की   PSP  postposition, common in indian langs
# 9                        मुख्य    JJ                       adjective 'big'
# 10                      श्रेणी    NN                 noun, singular 'desk'
# 11                        time   SYM                                    NA
# 12                          of   SYM                                    NA
# 13                   discovery   NNC                                    NA
# 14                          or   SYM                                    NA
# 15                   invention   NNC                                    NA
# 16                     फ्रीबेस    NN                 noun, singular 'desk'
# 17                  पहचानकर्ता    NN                 noun, singular 'desk'
# 18                       चित्र   NNC                                    NA
# 19                   द्रव्यमान    NN                 noun, singular 'desk'
# 20                          का   PSP  postposition, common in indian langs
# 21                         भाग    NN                 noun, singular 'desk'
# 22                      कॉमन्स    VM                             main verb
# 23                      श्रेणी    NN                 noun, singular 'desk'
# 24                        LCCN  NNPC                                    NA
# 25                   अभिज्ञापक    NN                 noun, singular 'desk'
# 26                     chemica    NN                 noun, singular 'desk'
# 27                           l   SYM                                    NA
# 28                     formula   NNC                                    NA
# 29                Encyclopædia  NNPC                                    NA
# 30                  Britannica  NNPC                                    NA
# 31                      Online  NNPC                                    NA
# 32                          ID   NNP      proper noun, singular 'Harrison'
# 33                          का   PSP  postposition, common in indian langs
# 34                      उदहारण    NN                 noun, singular 'desk'
# 35                          है    VM                             main verb
# 36                       स्रोत    NN                 noun, singular 'desk'
# 37                      द्वारा   PSP  postposition, common in indian langs
# 38                      वर्णित    JJ                       adjective 'big'
# 39                    Treccani    VM                             main verb
# 40                          ID    NN                 noun, singular 'desk'

# %%
#ip = nlp("""तत्व द्रव्यमान क्षुद्रातु का "चित्र" dicoverer खोजकर्ता या आविष्कारक क्या  chemical formula है""")
ip = nlp("""चित्र""")
# Out:
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
extract_pos(ip)
# Out:
#     word pos                    exp
# 0  चित्र  NN  noun, singular 'desk'

# %%
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'../questions_new.db')

# create the dataframe from a query
df = pd.read_sql_query("SELECT * FROM ELEMENTS", cnx)
df.head(60)
# Out:
#     SERIAL_NO                                           QUESTION
# 0           1  तत्व नाइट्रोजन का "DSSTOX_compound_identifier"...
# 1           2                  तत्व नाइट्रोजन का "UNII" क्या है?
# 2           3      तत्व नाइट्रोजन का "chemical formula" क्या है?
# 3           4  तत्व मेइट्नेरियम का "DSSTOX_compound_identifie...
# 4           5      तत्व मेइट्नेरियम का "LCCN अभिज्ञापक" क्या है?
# 5           6  तत्व मेइट्नेरियम का "स्रोत द्वारा वर्णित" क्या...
# 6           7         तत्व मेइट्नेरियम का "Treccani ID" क्या है?
# 7           8                तत्व मेइट्नेरियम का "UNII" क्या है?
# 8           9               तत्व मेइट्नेरियम का "चित्र" क्या है?
# 9          10           तत्व मेइट्नेरियम का "द्रव्यमान" क्या है?
# 10         11    तत्व मेइट्नेरियम का "chemical formula" क्या है?
# 11         12       तत्व क्रोमियम का "chemical formula" क्या है?
# 12         13                तत्व प्रोमीथियम का "चित्र" क्या है?
# 13         14            तत्व प्रोमीथियम का "द्रव्यमान" क्या है?
# 14         15                     तत्व हैसियम का "UNII" क्या है?
# 15         16                    तत्व हैसियम का "चित्र" क्या है?
# 16         17                तत्व हैसियम का "द्रव्यमान" क्या है?
# 17         18         तत्व हैसियम का "chemical formula" क्या है?
# 18         19      तत्व आइंस्टीनियम का "LCCN अभिज्ञापक" क्या है?
# 19         20           तत्व आइंस्टीनियम का "द्रव्यमान" क्या है?
# 20         21     तत्व ताम्र का "खोजकर्ता या आविष्कारक" क्या है?
# 21         22  तत्व टिन का "time of discovery or invention" क...
# 22         23       तत्व टिन का "खोजकर्ता या आविष्कारक" क्या है?
# 23         24                 तत्व ऐक्टिनियम का "चित्र" क्या है?
# 24         25      तत्व रदरफोर्डियम का "LCCN अभिज्ञापक" क्या है?
# 25         26                तत्व रदरफोर्डियम का "UNII" क्या है?
# 26         27               तत्व रदरफोर्डियम का "चित्र" क्या है?
# 27         28           तत्व रदरफोर्डियम का "द्रव्यमान" क्या है?
# 28         29                तत्व तेजातु का "द्रव्यमान" क्या है?
# 29         30  तत्व ऑक्सीजन का "DSSTOX_compound_identifier" क...
# 30         31                    तत्व ऑक्सीजन का "UNII" क्या है?
# 31         32        तत्व ऑक्सीजन का "chemical formula" क्या है?
# 32         33  तत्व आर्गन का "Encyclopædia Britannica Online ...
# 33         34       तत्व कैलीफोर्नियम का "कॉमन्स गैलरी" क्या है?
# 34         35          तत्व कैलीफोर्नियम का "द्रव्यमान" क्या है?
# 35         36          तत्व फर्मीयम का "LCCN अभिज्ञापक" क्या है?
# 36         37                   तत्व फर्मीयम का "चित्र" क्या है?
# 37         38  तत्व क्लोरीन का "DSSTOX_compound_identifier" क...
# 38         39                    तत्व क्लोरीन का "UNII" क्या है?
# 39         40        तत्व क्लोरीन का "chemical formula" क्या है?
# 40         41  तत्व आयोडिन का "DSSTOX_compound_identifier" क्...
# 41         42                     तत्व आयोडिन का "UNII" क्या है?
# 42         43         तत्व आयोडिन का "chemical formula" क्या है?
# 43         44  तत्व हाइड्रोजन का "DSSTOX_compound_identifier"...
# 44         45                  तत्व हाइड्रोजन का "UNII" क्या है?
# 45         46      तत्व हाइड्रोजन का "chemical formula" क्या है?
# 46         47            तत्व प्लूटोनियम का "द्रव्यमान" क्या है?
# 47         48            तत्व टैंटेलम का "कॉमन्स गैलरी" क्या है?
# 48         49         तत्व लिथियम का "chemical formula" क्या है?
# 49         50  तत्व बिस्मथ का "Encyclopædia Britannica Online...
# 50         51  तत्व बिस्मथ का "time of discovery or invention...
# 51         52    तत्व बिस्मथ का "खोजकर्ता या आविष्कारक" क्या है?
# 52         53      तत्व टाइटेनियम का "chemical formula" क्या है?
# 53         54         तत्व नोबेलियम का "LCCN अभिज्ञापक" क्या है?
# 54         55                  तत्व नोबेलियम का "चित्र" क्या है?
# 55         56              तत्व नोबेलियम का "द्रव्यमान" क्या है?
# 56         57      तत्व पोटैशिय का "फ्रीबेस पहचानकर्ता" क्या है?
# 57         58  तत्व फ्लोरीन का "DSSTOX_compound_identifier" क...
# 58         59                    तत्व फ्लोरीन का "UNII" क्या है?
# 59         60        तत्व फ्लोरीन का "chemical formula" क्या है?

# %%
import pandas as pd
#extract parts of speech
def extract_pos(doc):
    parsed_text = {'word':[], 'pos':[], 'exp':[]}
    for sent in doc.sentences:
        for wrd in sent.words:
            if wrd.pos in pos_dict.keys():
                pos_exp = pos_dict[wrd.pos]
            else:
                pos_exp = 'NA'
            parsed_text['word'].append(wrd.text)
            parsed_text['pos'].append(wrd.pos)
            parsed_text['exp'].append(pos_exp)
    #return a dataframe of pos and text
    return pd.DataFrame(parsed_text)

hindi_doc = nlp("""तत्व ऑक्सीजन का "खोजकर्ता या आविष्कारक" क्या है?""")
pos_dict = {
'CC': 'coordinating conjunction','CD': 'cardinal digit','DT': 'determiner',
'EX': 'existential there (like: \"there is\" ... think of it like \"there exists\")',
'FW': 'foreign word','IN':  'preposition/subordinating conjunction','JJ': 'adjective \'big\'',
'JJR': 'adjective, comparative \'bigger\'','JJS': 'adjective, superlative \'biggest\'',
'LS': 'list marker 1)','MD': 'modal could, will','NN': 'noun, singular \'desk\'',
'NNS': 'noun plural \'desks\'','NNP': 'proper noun, singular \'Harrison\'',
'NNPS': 'proper noun, plural \'Americans\'','PDT': 'predeterminer \'all the kids\'',
'POS': 'possessive ending parent\'s','PRP': 'personal pronoun I, he, she',
'PRP$': 'possessive pronoun my, his, hers','RB': 'adverb very, silently,',
'RBR': 'adverb, comparative better','RBS': 'adverb, superlative best',
'RP': 'particle give up','TO': 'to go \'to\' the store.','UH': 'interjection errrrrrrrm',
'VB': 'verb, base form take','VBD': 'verb, past tense took',
'VBG': 'verb, gerund/present participle taking','VBN': 'verb, past participle taken',
'VBP': 'verb, sing. present, non-3d take','VBZ': 'verb, 3rd person sing. present takes',
'WDT': 'wh-determiner which','WP': 'wh-pronoun who, what','WP$': 'possessive wh-pronoun whose',
'WRB': 'wh-abverb where, when','QF' : 'quantifier, bahut, thoda, kam (Hindi)','VM' : 'main verb',
'PSP' : 'postposition, common in indian langs','DEM' : 'demonstrative, common in indian langs'
}
print(extract_pos(hindi_doc))
# Out:
#          word  pos                                   exp
# 0        तत्व   NN                 noun, singular 'desk'
# 1     ऑक्सीजन   NN                 noun, singular 'desk'
# 2          का  PSP  postposition, common in indian langs
# 3           "  SYM                                    NA
# 4    खोजकर्ता   NN                 noun, singular 'desk'
# 5          या   CC              coordinating conjunction
# 6   आविष्कारक   NN                 noun, singular 'desk'
# 7           "  SYM                                    NA
# 8        क्या   WQ                                    NA
# 9          है   VM                             main verb
# 10          ?  SYM                                    NA
# /pytorch/aten/src/ATen/native/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
